# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.141-py3-none-any.whl.metadata (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle>=3.1.1 in /usr/local/lib/python3.13/dist-packages (from ultralytics) (3.1.2)
# Requirement already satisfied: filelock>=3.16.1 in /usr/local/lib/python3.13/dist-packages (from ultralytics) (3.32.4)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.13/dist-packages (from ultralytics) (2.1.3)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.13/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python!=4.13.0.90,>=4.7.0 in /usr/local/lib/python3.13/dist-packages (from ultralytics) (5.0.0.93)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.13/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.13/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.13/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.13/dist-packages (from ultralytics) (2.11.0+cu128)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.13/dist-packages (from ultralytics) (0.26.0+cu128)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.13/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.13/dist-packages (from ultralytics) (1.35.2)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in /usr/local/lib/python3.13/dist-packages (from ultralytics) (13.610.43)
# Collecting ultralytics-thop>=2.1.6 (from ultralytics)
#   Downloading ultralytics_thop-2.1.6-py3-none-any.whl.metadata (13 kB)
# Collecting ultralytics-platform>=0.1.3 (from ultralytics)
#   Downloading ultralytics_platform-0.1.21-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.3.0->ultralytics) (26.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.13/dist-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.23.0->ultralytics) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests>=2.23.0->ultralytics) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests>=2.23.0->ultralytics) (2026.7.22)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.0->ultralytics) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.0->ultralytics) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.0->ultralytics) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.0->ultralytics) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.0->ultralytics) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.0->ultralytics) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: httpx<1,>=0.28 in /usr/local/lib/python3.13/dist-packages (from ultralytics-platform>=0.1.3->ultralytics) (0.28.1)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.8.0->ultralytics) (1.7.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.28->ultralytics-platform>=0.1.3->ultralytics) (4.14.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.28->ultralytics-platform>=0.1.3->ultralytics) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1,>=0.28->ultralytics-platform>=0.1.3->ultralytics) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.4.141-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 52.6 MB/s eta 0:00:00
# Downloading ultralytics_platform-0.1.21-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 5.8 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.1.6-py3-none-any.whl (30 kB)
# Installing collected packages: ultralytics-platform, ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.4.141 ultralytics-platform-0.1.21 ultralytics-thop-2.1.6

# %%
import ultralytics
ultralytics.__version__
# Out:
# '8.4.141'

# %%
import cv2
import pandas as pd
import os
import time

from ultralytics import YOLO
from tracker import *

model = YOLO("yolo26m.pt")

# %%
import os

print("Current directory:", os.getcwd())
print("\nFiles:")
print(os.listdir())
# Out:
# Current directory: /content
#
# Files:
# ['.config', 'tracker.py', 'sample_data']

# %%
class_list = ['person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven',
              'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']

# %%
tracker=Tracker()
count=0

# %%
cap=cv2.VideoCapture("content/highway.mp4")

# %%
down = {}
up = {}
counter_down = []
counter_up = []

red_line_y = 198
blue_line_y = 268
offset = 6

# Create a folder to save frames
if not os.path.exists('detected_frames'):
    os.makedirs('detected_frames')

fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('output.avi', fourcc, 20.0, (1020, 500))

while True:
    ret, frame = cap.read()
    if not ret:
        break
    count += 1
    # if count % 2 != 0:
    #     continue
    frame = cv2.resize(frame, (1020, 500))

    results = model.predict(frame)
    a = results[0].boxes.data
    a = a.detach().cpu().numpy()
    px = pd.DataFrame(a).astype("float")
    list = []

    for index, row in px.iterrows():
        x1 = int(row[0])
        y1 = int(row[1])
        x2 = int(row[2])
        y2 = int(row[3])
        d = int(row[5])
        c = class_list[d]
        if 'car' in c:
            list.append([x1, y1, x2, y2])
    bbox_id = tracker.update(list)

    for bbox in bbox_id:
        x3, y3, x4, y4, id = bbox
        cx = int(x3 + x4) // 2
        cy = int(y3 + y4) // 2

        if red_line_y<(cy+offset) and red_line_y > (cy-offset):
           down[id]=time.time()   # current time when vehichle touch the first line
        if id in down:

           if blue_line_y<(cy+offset) and blue_line_y > (cy-offset):
             elapsed_time=time.time() - down[id]  # current time when vehicle touch the second line. Also we a re minusing the previous time ( current time of line 1)
             if counter_down.count(id)==0:
                counter_down.append(id)
                distance = 10 # meters
                a_speed_ms = distance / elapsed_time
                a_speed_kh = a_speed_ms * 3.6  # this will give kilometers per hour for each vehicle. This is the condition for going downside
                cv2.circle(frame,(cx,cy),4,(0,0,255),-1)
                cv2.rectangle(frame, (x3, y3), (x4, y4), (0, 255, 0), 2)  # Draw bounding box
                cv2.putText(frame,str(id),(x3,y3),cv2.FONT_HERSHEY_COMPLEX,0.6,(255,255,255),1)
                cv2.putText(frame,str(int(a_speed_kh))+'Km/h',(x4,y4 ),cv2.FONT_HERSHEY_COMPLEX,0.8,(0,255,255),2)


        #####going UP blue line#####
        if blue_line_y<(cy+offset) and blue_line_y > (cy-offset):
           up[id]=time.time()
        if id in up:

           if red_line_y<(cy+offset) and red_line_y > (cy-offset):
             elapsed1_time=time.time() - up[id]
             # formula of speed= distance/time
             if counter_up.count(id)==0:
                counter_up.append(id)
                distance1 = 10 # meters  (Distance between the 2 lines is 10 meters )
                a_speed_ms1 = distance1 / elapsed1_time
                a_speed_kh1 = a_speed_ms1 * 3.6
                cv2.circle(frame,(cx,cy),4,(0,0,255),-1)
                cv2.rectangle(frame, (x3, y3), (x4, y4), (0, 255, 0), 2)  # Draw bounding box
                cv2.putText(frame,str(id),(x3,y3),cv2.FONT_HERSHEY_COMPLEX,0.6,(255,255,255),1)
                cv2.putText(frame,str(int(a_speed_kh1))+'Km/h',(x4,y4),cv2.FONT_HERSHEY_COMPLEX,0.8,(0,255,255),2)




    text_color = (0, 0, 0)  # Black color for text
    yellow_color = (0, 255, 255)  # Yellow color for background
    red_color = (0, 0, 255)  # Red color for lines
    blue_color = (255, 0, 0)  # Blue color for lines

    cv2.rectangle(frame, (0, 0), (250, 90), yellow_color, -1)

    cv2.line(frame, (172, 198), (774, 198), red_color, 2)
    cv2.putText(frame, ('Red Line'), (172, 198), cv2.FONT_HERSHEY_SIMPLEX, 0.5, text_color, 1, cv2.LINE_AA)

    cv2.line(frame, (8, 268), (927, 268), blue_color, 2)
    cv2.putText(frame, ('Blue Line'), (8, 268), cv2.FONT_HERSHEY_SIMPLEX, 0.5, text_color, 1, cv2.LINE_AA)

    cv2.putText(frame, ('Going Down - ' + str(len(counter_down))), (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.5, text_color, 1, cv2.LINE_AA)
    cv2.putText(frame, ('Going Up - ' + str(len(counter_up))), (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.5, text_color, 1, cv2.LINE_AA)

    # Save frame
    frame_filename = f'detected_frames/frame_{count}.jpg'
    cv2.imwrite(frame_filename, frame)

    out.write(frame)

    # Don't use cv2.imshow() in Google Colab
    #if cv2.waitKey(0) & 0xFF == 27:
        #break

cap.release()
out.release()

print("Processing completed!")
print("Total Going Down:", len(counter_down))
print("Total Going Up:", len(counter_up))
# Out:
# Processing completed!
# Total Going Down: 0
# Total Going Up: 0

# %%
import cv2
import pandas as pd
import os
import time

# Create tracker
tracker = Tracker()

# Frame counter
count = 0

# Open video
cap = cv2.VideoCapture("/content/highway_mini.mp4")

if not cap.isOpened():
    raise Exception("Could not open highway_mini.mp4")

# Get original FPS
fps = cap.get(cv2.CAP_PROP_FPS)

if fps <= 0:
    fps = 20

print("Video FPS:", fps)

# Output video size
width = 1020
height = 500

# Create output folder
os.makedirs("/content/detected_frames", exist_ok=True)

# Video writer
fourcc = cv2.VideoWriter_fourcc(*"mp4v")

out = cv2.VideoWriter(
    "/content/output.mp4",
    fourcc,
    fps,
    (width, height)
)

# Class names directly from YOLO model
class_list = model.names

print("Processing video...")

while True:

    ret, frame = cap.read()

    if not ret:
        break

    count += 1

    # Resize frame
    frame = cv2.resize(frame, (width, height))

    # YOLO prediction
    results = model.predict(
        frame,
        verbose=False
    )

    # Get detections
    a = results[0].boxes.data

    # Convert tensor to NumPy
    a = a.detach().cpu().numpy()

    # Convert to DataFrame
    px = pd.DataFrame(a).astype("float")

    # Store car bounding boxes
    detections = []

    for index, row in px.iterrows():

        x1 = int(row[0])
        y1 = int(row[1])
        x2 = int(row[2])
        y2 = int(row[3])

        # Class ID
        d = int(row[5])

        # Class name
        c = class_list[d]

        # Only detect cars
        if c == "car":

            detections.append(
                [x1, y1, x2, y2]
            )

    # Update tracker
    bbox_id = tracker.update(detections)

    # Draw tracked vehicles
    for bbox in bbox_id:

        x3, y3, x4, y4, id = bbox

        # Center point
        cx = int((x3 + x4) / 2)
        cy = int((y3 + y4) / 2)

        # Draw center
        cv2.circle(
            frame,
            (cx, cy),
            4,
            (0, 0, 255),
            -1
        )

        # Draw bounding box
        cv2.rectangle(
            frame,
            (x3, y3),
            (x4, y4),
            (0, 255, 0),
            2
        )

        # Draw tracking ID
        cv2.putText(
            frame,
            str(id),
            (cx, cy),
            cv2.FONT_HERSHEY_COMPLEX,
            0.8,
            (0, 255, 255),
            2
        )

    # ------------------------------------------------
    # LINE SETTINGS
    # ------------------------------------------------

    red_line_y = 198
    blue_line_y = 268
    offset = 7

    # Colors (B, G, R)
    text_color = (255, 255, 255)
    red_color = (0, 0, 255)
    blue_color = (255, 0, 0)

    # Red line
    cv2.line(
        frame,
        (172, red_line_y),
        (774, red_line_y),
        red_color,
        3
    )

    cv2.putText(
        frame,
        "Red Line",
        (172, red_line_y),
        cv2.FONT_HERSHEY_SIMPLEX,
        0.5,
        text_color,
        1,
        cv2.LINE_AA
    )

    # Blue line
    cv2.line(
        frame,
        (8, blue_line_y),
        (927, blue_line_y),
        blue_color,
        3
    )

    cv2.putText(
        frame,
        "Blue Line",
        (8, blue_line_y),
        cv2.FONT_HERSHEY_SIMPLEX,
        0.5,
        text_color,
        1,
        cv2.LINE_AA
    )

    # Save processed frame
    frame_filename = (
        f"/content/detected_frames/frame_{count}.jpg"
    )

    cv2.imwrite(
        frame_filename,
        frame
    )

    # Write frame to output video
    out.write(frame)

    # Progress
    if count % 50 == 0:
        print(f"Processed {count} frames")

# Release resources
cap.release()
out.release()

print("================================")
print("Video processing completed!")
print("Total frames:", count)
print("Output:", "/content/output.mp4")
print("================================")
# Out:
# Video FPS: 25.0
# Processing video...
# Processed 50 frames
# Processed 100 frames
# Processed 150 frames
# Processed 200 frames
# ================================
# Video processing completed!
# Total frames: 226
# Output: /content/output.mp4
# ================================

# %%
import cv2
import pandas as pd
import os
import time

from ultralytics import YOLO
from tracker import Tracker


# ============================================================
# LOAD YOLO26m
# ============================================================

model = YOLO("yolo26m.pt")

# Get class names directly from the model
class_list = model.names

print("Model loaded successfully!")


# ============================================================
# TRACKER
# ============================================================

tracker = Tracker()

count = 0


# ============================================================
# INPUT VIDEO
# ============================================================

video_path = "/content/highway_mini.mp4"

cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    raise Exception("ERROR: Could not open highway_mini.mp4")


# ============================================================
# VIDEO INFORMATION
# ============================================================

fps = cap.get(cv2.CAP_PROP_FPS)

if fps <= 0:
    fps = 20

print("Video FPS:", fps)


# ============================================================
# OUTPUT VIDEO
# ============================================================

output_path = "/content/output.mp4"

width = 1020
height = 500

fourcc = cv2.VideoWriter_fourcc(*"mp4v")

out = cv2.VideoWriter(
    output_path,
    fourcc,
    fps,
    (width, height)
)


# ============================================================
# UP / DOWN DICTIONARIES
# ============================================================

down = {}
up = {}

counter_down = []
counter_up = []


# ============================================================
# PROCESS VIDEO
# ============================================================

while True:

    ret, frame = cap.read()

    if not ret:
        break

    count += 1

    # Resize frame
    frame = cv2.resize(frame, (1020, 500))


    # ========================================================
    # YOLO PREDICTION
    # ========================================================

    results = model.predict(
        frame,
        verbose=False
    )


    # Get detection data
    a = results[0].boxes.data

    # Convert tensor to NumPy
    a = a.detach().cpu().numpy()

    # Convert to DataFrame
    px = pd.DataFrame(a).astype("float")


    # ========================================================
    # CAR DETECTIONS
    # ========================================================

    detections = []


    for index, row in px.iterrows():

        x1 = int(row[0])
        y1 = int(row[1])
        x2 = int(row[2])
        y2 = int(row[3])

        # Class ID
        d = int(row[5])

        # Class name
        c = class_list[d]


        # Only detect cars
        if c == "car":

            detections.append(
                [x1, y1, x2, y2]
            )


    # ========================================================
    # TRACK OBJECTS
    # ========================================================

    bbox_id = tracker.update(detections)


    # ========================================================
    # LINE SETTINGS
    # ========================================================

    red_line_y = 198
    blue_line_y = 268

    offset = 7


    # ========================================================
    # PROCESS TRACKED VEHICLES
    # ========================================================

    for bbox in bbox_id:

        x3, y3, x4, y4, id = bbox

        # Center point
        cx = int((x3 + x4) / 2)
        cy = int((y3 + y4) / 2)


        # ====================================================
        # RED LINE
        # ====================================================

        if red_line_y < (cy + offset) and red_line_y > (cy - offset):

            # Store time when vehicle touches red line
            down[id] = time.time()


            # =================================================
            # DRAW VEHICLE
            # =================================================

            cv2.circle(
                frame,
                (cx, cy),
                4,
                (0, 0, 255),
                -1
            )

            cv2.rectangle(
                frame,
                (x3, y3),
                (x4, y4),
                (0, 255, 0),
                2
            )

            cv2.putText(
                frame,
                str(id),
                (cx, cy),
                cv2.FONT_HERSHEY_COMPLEX,
                0.8,
                (0, 255, 255),
                2
            )


            # =================================================
            # PRINT READABLE TIME
            # =================================================

            formatted_time = time.strftime(
                "%Y-%m-%d %H:%M:%S",
                time.localtime(down[id])
            )

            print(
                "Vehicle ID:",
                id,
                "| Red Line Time:",
                formatted_time
            )


    # ========================================================
    # DRAW RED LINE
    # ========================================================

    text_color = (255, 255, 255)

    red_color = (0, 0, 255)

    blue_color = (255, 0, 0)

    green_color = (0, 255, 0)


    cv2.line(
        frame,
        (172, 198),
        (774, 198),
        red_color,
        3
    )

    cv2.putText(
        frame,
        "Red Line",
        (172, 198),
        cv2.FONT_HERSHEY_SIMPLEX,
        0.5,
        text_color,
        1,
        cv2.LINE_AA
    )


    # ========================================================
    # DRAW BLUE LINE
    # ========================================================

    cv2.line(
        frame,
        (8, 268),
        (927, 268),
        blue_color,
        3
    )

    cv2.putText(
        frame,
        "Blue Line",
        (8, 268),
        cv2.FONT_HERSHEY_SIMPLEX,
        0.5,
        text_color,
        1,
        cv2.LINE_AA
    )


    # ========================================================
    # WRITE FRAME TO OUTPUT VIDEO
    # ========================================================

    out.write(frame)


    # ========================================================
    # PROGRESS
    # ========================================================

    if count % 50 == 0:

        print(
            "Processed frames:",
            count
        )


# ============================================================
# RELEASE VIDEO
# ============================================================

cap.release()
out.release()


print("\n====================================")
print("VIDEO PROCESSING COMPLETED")
print("====================================")
print("Total frames:", count)
print("Output:", output_path)
print("Vehicles touching red line:", len(down))
print("====================================")
# Out:
# Model loaded successfully!
# Video FPS: 25.0
# Vehicle ID: 2 | Red Line Time: 2026-09-05 19:29:42
# Vehicle ID: 2 | Red Line Time: 2026-09-05 19:29:42
# Vehicle ID: 2 | Red Line Time: 2026-09-05 19:29:42
# Vehicle ID: 1 | Red Line Time: 2026-09-05 19:29:42
# Vehicle ID: 1 | Red Line Time: 2026-09-05 19:29:42
# Vehicle ID: 1 | Red Line Time: 2026-09-05 19:29:42
# Vehicle ID: 1 | Red Line Time: 2026-09-05 19:29:42
# Vehicle ID: 1 | Red Line Time: 2026-09-05 19:29:42
# Vehicle ID: 1 | Red Line Time: 2026-09-05 19:29:42
# Vehicle ID: 1 | Red Line Time: 2026-09-05 19:29:42
# Vehicle ID: 4 | Red Line Time: 2026-09-05 19:29:42
# Vehicle ID: 0 | Red Line Time: 2026-09-05 19:29:42
# Vehicle ID: 4 | Red Line Time: 2026-09-05 19:29:42
# Vehicle ID: 0 | Red Line Time: 2026-09-05 19:29:42
# Vehicle ID: 4 | Red Line Time: 2026-09-05 19:29:42
# Vehicle ID: 0 | Red Line Time: 2026-09-05 19:29:42
# Vehicle ID: 4 | Red Line Time: 2026-09-05 19:29:42
# Vehicle ID: 0 | Red Line Time: 2026-09-05 19:29:42
# Vehicle ID: 4 | Red Line Time: 2026-09-05 19:29:42
# Vehicle ID: 4 | Red Line Time: 2026-09-05 19:29:42
# Vehicle ID: 0 | Red Line Time: 2026-09-05 19:29:42
# Vehicle ID: 0 | Red Line Time: 2026-09-05 19:29:43
# Vehicle ID: 4 | Red Line Time: 2026-09-05 19:29:43
# Vehicle ID: 0 | Red Line Time: 2026-09-05 19:29:43
# Vehicle ID: 0 | Red Line Time: 2026-09-05 19:29:43
# Vehicle ID: 16 | Red Line Time: 2026-09-05 19:29:43
# Vehicle ID: 16 | Red Line Time: 2026-09-05 19:29:43
# Vehicle ID: 16 | Red Line Time: 2026-09-05 19:29:43
# Vehicle ID: 16 | Red Line Time: 2026-09-05 19:29:43
# Vehicle ID: 16 | Red Line Time: 2026-09-05 19:29:43
# Vehicle ID: 16 | Red Line Time: 2026-09-05 19:29:43
# Processed frames: 50
# Vehicle ID: 6 | Red Line Time: 2026-09-05 19:29:43
# Vehicle ID: 6 | Red Line Time: 2026-09-05 19:29:43
# Vehicle ID: 6 | Red Line Time: 2026-09-05 19:29:43
# Vehicle ID: 6 | Red Line Time: 2026-09-05 19:29:43
# Vehicle ID: 6 | Red Line Time: 2026-09-05 19:29:43
# Vehicle ID: 6 | Red Line Time: 2026-09-05 19:29:43
# Vehicle ID: 6 | Red Line Time: 2026-09-05 19:29:43
# Vehicle ID: 6 | Red Line Time: 2026-09-05 19:29:43
# Vehicle ID: 21 | Red Line Time: 2026-09-05 19:29:44
# Vehicle ID: 6 | Red Line Time: 2026-09-05 19:29:44
# Vehicle ID: 21 | Red Line Time: 2026-09-05 19:29:44
# Vehicle ID: 21 | Red Line Time: 2026-09-05 19:29:44
# Vehicle ID: 21 | Red Line Time: 2026-09-05 19:29:44
# Vehicle ID: 21 | Red Line Time: 2026-09-05 19:29:44
# Vehicle ID: 32 | Red Line Time: 2026-09-05 19:29:44
# Vehicle ID: 32 | Red Line Time: 2026-09-05 19:29:44
# Vehicle ID: 32 | Red Line Time: 2026-09-05 19:29:44
# Vehicle ID: 32 | Red Line Time: 2026-09-05 19:29:44
# Vehicle ID: 32 | Red Line Time: 2026-09-05 19:29:44
# Vehicle ID: 32 | Red Line Time: 2026-09-05 19:29:44
# Vehicle ID: 32 | Red Line Time: 2026-09-05 19:29:44
# Vehicle ID: 32 | Red Line Time: 2026-09-05 19:29:44
# Vehicle ID: 32 | Red Line Time: 2026-09-05 19:29:44
# Vehicle ID: 32 | Red Line Time: 2026-09-05 19:29:44
# Processed frames: 100
# Vehicle ID: 34 | Red Line Time: 2026-09-05 19:29:45
# Vehicle ID: 34 | Red Line Time: 2026-09-05 19:29:45
# Vehicle ID: 34 | Red Line Time: 2026-09-05 19:29:45
# Vehicle ID: 34 | Red Line Time: 2026-09-05 19:29:45
# Vehicle ID: 34 | Red Line Time: 2026-09-05 19:29:45
# Vehicle ID: 34 | Red Line Time: 2026-09-05 19:29:45
# Vehicle ID: 34 | Red Line Time: 2026-09-05 19:29:45
# Vehicle ID: 34 | Red Line Time: 2026-09-05 19:29:45
# Vehicle ID: 60 | Red Line Time: 2026-09-05 19:29:46
# Vehicle ID: 60 | Red Line Time: 2026-09-05 19:29:46
# Vehicle ID: 60 | Red Line Time: 2026-09-05 19:29:46
# Vehicle ID: 60 | Red Line Time: 2026-09-05 19:29:46
# Vehicle ID: 60 | Red Line Time: 2026-09-05 19:29:46
# Vehicle ID: 60 | Red Line Time: 2026-09-05 19:29:46
# Processed frames: 150
# Vehicle ID: 62 | Red Line Time: 2026-09-05 19:29:46
# Vehicle ID: 62 | Red Line Time: 2026-09-05 19:29:46
# Vehicle ID: 62 | Red Line Time: 2026-09-05 19:29:46
# Vehicle ID: 62 | Red Line Time: 2026-09-05 19:29:46
# Vehicle ID: 62 | Red Line Time: 2026-09-05 19:29:46
# Vehicle ID: 62 | Red Line Time: 2026-09-05 19:29:46
# Vehicle ID: 62 | Red Line Time: 2026-09-05 19:29:46
# Vehicle ID: 62 | Red Line Time: 2026-09-05 19:29:46
# Vehicle ID: 62 | Red Line Time: 2026-09-05 19:29:46
# Vehicle ID: 63 | Red Line Time: 2026-09-05 19:29:47
# Vehicle ID: 63 | Red Line Time: 2026-09-05 19:29:47
# Vehicle ID: 63 | Red Line Time: 2026-09-05 19:29:47
# Vehicle ID: 63 | Red Line Time: 2026-09-05 19:29:47
# Vehicle ID: 63 | Red Line Time: 2026-09-05 19:29:47
# Vehicle ID: 63 | Red Line Time: 2026-09-05 19:29:47
# Vehicle ID: 63 | Red Line Time: 2026-09-05 19:29:47
# Vehicle ID: 63 | Red Line Time: 2026-09-05 19:29:47
# Processed frames: 200
# Vehicle ID: 74 | Red Line Time: 2026-09-05 19:29:47
# Vehicle ID: 74 | Red Line Time: 2026-09-05 19:29:47
# Vehicle ID: 74 | Red Line Time: 2026-09-05 19:29:47
# Vehicle ID: 74 | Red Line Time: 2026-09-05 19:29:47
# Vehicle ID: 74 | Red Line Time: 2026-09-05 19:29:47
# Vehicle ID: 74 | Red Line Time: 2026-09-05 19:29:47
# Vehicle ID: 74 | Red Line Time: 2026-09-05 19:29:47
# Vehicle ID: 94 | Red Line Time: 2026-09-05 19:29:47
# Vehicle ID: 74 | Red Line Time: 2026-09-05 19:29:47
# Vehicle ID: 94 | Red Line Time: 2026-09-05 19:29:47
# Vehicle ID: 74 | Red Line Time: 2026-09-05 19:29:47
# Vehicle ID: 94 | Red Line Time: 2026-09-05 19:29:47
# Vehicle ID: 94 | Red Line Time: 2026-09-05 19:29:47
# Vehicle ID: 94 | Red Line Time: 2026-09-05 19:29:47
# Vehicle ID: 94 | Red Line Time: 2026-09-05 19:29:47
# Vehicle ID: 94 | Red Line Time: 2026-09-05 19:29:48
# Vehicle ID: 57 | Red Line Time: 2026-09-05 19:29:48
# Vehicle ID: 57 | Red Line Time: 2026-09-05 19:29:48
# Vehicle ID: 57 | Red Line Time: 2026-09-05 19:29:48
# Vehicle ID: 57 | Red Line Time: 2026-09-05 19:29:48
# Vehicle ID: 57 | Red Line Time: 2026-09-05 19:29:48
#
# ====================================
# VIDEO PROCESSING COMPLETED
# ====================================
# Total frames: 226
# Output: /content/output.mp4
# Vehicles touching red line: 15
# ====================================

# %%
import cv2
import pandas as pd
import os
import time

from ultralytics import YOLO
from tracker import Tracker


# ============================================================
# YOLO26m MODEL
# ============================================================

model = YOLO("yolo26m.pt")

# Get class names directly from the model
class_list = model.names


# ============================================================
# TRACKER
# ============================================================

tracker = Tracker()

count = 0


# ============================================================
# VIDEO INPUT
# ============================================================

video_path = "/content/highway_mini.mp4"

cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    raise Exception("Could not open highway_mini.mp4")


# ============================================================
# VIDEO SETTINGS
# ============================================================

fps = cap.get(cv2.CAP_PROP_FPS)

if fps <= 0:
    fps = 20

width = 1020
height = 500


# ============================================================
# OUTPUT VIDEO
# ============================================================

output_path = "/content/output1.mp4"

fourcc = cv2.VideoWriter_fourcc(*"mp4v")

out = cv2.VideoWriter(
    output_path,
    fourcc,
    fps,
    (width, height)
)


# ============================================================
# UP / DOWN
# ============================================================

down = {}
up = {}

counter_down = []
counter_up = []


# ============================================================
# LINE SETTINGS
# ============================================================

red_line_y = 198
blue_line_y = 268
offset = 7


print("Starting video processing...")


# ============================================================
# MAIN LOOP
# ============================================================

while True:

    ret, frame = cap.read()

    if not ret:
        break

    count += 1


    # --------------------------------------------------------
    # RESIZE FRAME
    # --------------------------------------------------------

    frame = cv2.resize(
        frame,
        (width, height)
    )


    # --------------------------------------------------------
    # YOLO26 DETECTION
    # --------------------------------------------------------

    results = model.predict(
        frame,
        verbose=False
    )


    # Get detection tensor
    a = results[0].boxes.data

    # Convert tensor to NumPy
    a = a.detach().cpu().numpy()

    # Convert to DataFrame
    px = pd.DataFrame(a).astype("float")


    # --------------------------------------------------------
    # CAR DETECTIONS
    # --------------------------------------------------------

    detections = []


    for index, row in px.iterrows():

        x1 = int(row[0])
        y1 = int(row[1])
        x2 = int(row[2])
        y2 = int(row[3])

        # Class ID
        d = int(row[5])

        # Class name
        c = class_list[d]


        # Only cars
        if c == "car":

            detections.append(
                [x1, y1, x2, y2]
            )


    # --------------------------------------------------------
    # TRACKING
    # --------------------------------------------------------

    bbox_id = tracker.update(detections)


    # --------------------------------------------------------
    # PROCESS TRACKED CARS
    # --------------------------------------------------------

    for bbox in bbox_id:

        x3, y3, x4, y4, id = bbox

        # Center point
        cx = int((x3 + x4) / 2)
        cy = int((y3 + y4) / 2)


        # ----------------------------------------------------
        # BLUE LINE CONDITION
        # ----------------------------------------------------

        if (
            blue_line_y < (cy + offset)
            and
            blue_line_y > (cy - offset)
        ):

            # Store time
            up[id] = time.time()


            # Draw center
            cv2.circle(
                frame,
                (cx, cy),
                4,
                (0, 0, 255),
                -1
            )


            # Draw ID
            cv2.putText(
                frame,
                str(id),
                (cx, cy),
                cv2.FONT_HERSHEY_COMPLEX,
                0.8,
                (0, 255, 255),
                2
            )


            # Add ID only once
            if id not in counter_up:

                counter_up.append(id)


    # --------------------------------------------------------
    # PRINT BLUE LINE DATA
    # --------------------------------------------------------

    if len(up) > 0:
        print("Blue line:", up)


    # --------------------------------------------------------
    # COLORS
    # --------------------------------------------------------

    text_color = (255, 255, 255)

    red_color = (0, 0, 255)

    blue_color = (255, 0, 0)

    green_color = (0, 255, 0)


    # --------------------------------------------------------
    # RED LINE
    # --------------------------------------------------------

    cv2.line(
        frame,
        (172, red_line_y),
        (774, red_line_y),
        red_color,
        3
    )

    cv2.putText(
        frame,
        "Red Line",
        (172, red_line_y),
        cv2.FONT_HERSHEY_SIMPLEX,
        0.5,
        text_color,
        1,
        cv2.LINE_AA
    )


    # --------------------------------------------------------
    # BLUE LINE
    # --------------------------------------------------------

    cv2.line(
        frame,
        (8, blue_line_y),
        (927, blue_line_y),
        blue_color,
        3
    )

    cv2.putText(
        frame,
        "Blue Line",
        (8, blue_line_y),
        cv2.FONT_HERSHEY_SIMPLEX,
        0.5,
        text_color,
        1,
        cv2.LINE_AA
    )


    # --------------------------------------------------------
    # WRITE OUTPUT FRAME
    # --------------------------------------------------------

    out.write(frame)


    # --------------------------------------------------------
    # PROGRESS
    # --------------------------------------------------------

    if count % 50 == 0:

        print(
            "Processed frames:",
            count
        )


# ============================================================
# RELEASE
# ============================================================

cap.release()
out.release()


print()
print("======================================")
print("VIDEO PROCESSING COMPLETED")
print("======================================")
print("Total frames:", count)
print("Vehicles crossing blue line:", len(counter_up))
print("Output file:", output_path)
print("======================================")
# Out:
# Starting video processing...
# Blue line: {1: 1788636677.2502148}
# Blue line: {1: 1788636677.2828631}
# Blue line: {1: 1788636677.3124895}
# Blue line: {1: 1788636677.3124895}
# Blue line: {1: 1788636677.3124895}
# Blue line: {1: 1788636677.3124895}
# Blue line: {1: 1788636677.3124895}
# Blue line: {1: 1788636677.3124895}
# Blue line: {1: 1788636677.3124895}
# Blue line: {1: 1788636677.3124895}
# Blue line: {1: 1788636677.3124895}
# Blue line: {1: 1788636677.3124895}
# Blue line: {1: 1788636677.3124895}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.636136}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273}
# Processed frames: 50
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9337132}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.0821157}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.106805}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.1329157}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6331758}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.6591508}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.6837862}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Processed frames: 100
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8188603}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8445807}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8677118}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921}
# Processed frames: 150
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.5604427}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.5982065}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6264546, 60: 1788636680.6265311}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636680.9765265}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0020707}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0314736}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152}
# Processed frames: 200
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152, 80: 1788636681.7508585}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152, 80: 1788636681.7745907}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152, 80: 1788636681.7981896}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152, 80: 1788636681.824994}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152, 80: 1788636681.848674}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152, 80: 1788636681.8745573}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152, 80: 1788636681.8745573}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152, 80: 1788636681.8745573, 63: 1788636681.9212756}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152, 80: 1788636681.8745573, 63: 1788636681.9446032}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152, 80: 1788636681.8745573, 63: 1788636681.9683483}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152, 80: 1788636681.8745573, 63: 1788636681.9926789}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152, 80: 1788636681.8745573, 63: 1788636681.9926789}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152, 80: 1788636681.8745573, 63: 1788636681.9926789}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152, 80: 1788636681.8745573, 63: 1788636681.9926789}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152, 80: 1788636681.8745573, 63: 1788636681.9926789}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152, 80: 1788636681.8745573, 63: 1788636681.9926789}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152, 80: 1788636681.8745573, 63: 1788636681.9926789}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152, 80: 1788636681.8745573, 63: 1788636681.9926789}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152, 80: 1788636681.8745573, 63: 1788636681.9926789}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152, 80: 1788636681.8745573, 63: 1788636681.9926789}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152, 80: 1788636681.8745573, 63: 1788636681.9926789}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152, 80: 1788636681.8745573, 63: 1788636681.9926789}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152, 80: 1788636681.8745573, 63: 1788636681.9926789}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152, 80: 1788636681.8745573, 63: 1788636681.9926789}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152, 80: 1788636681.8745573, 63: 1788636681.9926789}
# Blue line: {1: 1788636677.3124895, 4: 1788636677.6646273, 16: 1788636677.9584196, 32: 1788636678.157265, 21: 1788636678.6590674, 6: 1788636678.7084203, 62: 1788636679.8914921, 34: 1788636680.6503623, 60: 1788636680.6504087, 74: 1788636681.0677152, 80: 1788636681.8745573, 63: 1788636681.9926789}
#
# ======================================
# VIDEO PROCESSING COMPLETED
# ======================================
# Total frames: 226
# Vehicles crossing blue line: 12
# Output file: /content/output1.mp4
# ======================================

# %% [markdown]
# **This show us result in cell**

# %%
# ============================================================
# 1. INSTALL ULTRALYTICS
# ============================================================

# !pip install -q ultralytics


# ============================================================
# 2. IMPORT LIBRARIES
# ============================================================

import cv2
import os
import pandas as pd

from ultralytics import YOLO
from tracker import Tracker

from IPython.display import Video, display


# ============================================================
# 3. LOAD YOLO26m MODEL
# ============================================================

model = YOLO("yolo26m.pt")

print("YOLO26m loaded successfully")


# ============================================================
# 4. VIDEO INPUT
# ============================================================

video_path = "/content/highway.mp4"

cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    raise ValueError(
        f"Could not open video: {video_path}"
    )

print("Video opened successfully")


# ============================================================
# 5. GET VIDEO INFORMATION
# ============================================================

fps = cap.get(cv2.CAP_PROP_FPS)

if fps <= 0:
    fps = 20.0

total_frames = int(
    cap.get(cv2.CAP_PROP_FRAME_COUNT)
)

video_width = int(
    cap.get(cv2.CAP_PROP_FRAME_WIDTH)
)

video_height = int(
    cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
)

video_duration = total_frames / fps


print("--------------------------------------")
print(f"Video FPS       : {fps:.2f}")
print(f"Total frames    : {total_frames}")
print(f"Original size   : {video_width} x {video_height}")
print(f"Duration        : {video_duration:.2f} seconds")
print("--------------------------------------")


# ============================================================
# 6. CLASS LIST
# ============================================================

# Use the class names directly from YOLO26m

class_list = model.names

print("YOLO Classes:")
print(class_list)


# ============================================================
# 7. CREATE TRACKER
# ============================================================

tracker = Tracker()

# Vehicles crossing red line
down = {}

# Vehicles crossing blue line
up = {}

# Completed vehicles
counter_down = []
counter_up = []


# ============================================================
# 8. SPEED STORAGE
# ============================================================

# Store calculated speeds
speed_down = {}
speed_up = {}


# ============================================================
# 9. LINE SETTINGS
# ============================================================

red_line_y = 198
blue_line_y = 268

offset = 6

# Distance between red and blue lines
DISTANCE_METERS = 10


# ============================================================
# 10. CREATE FOLDER FOR DETECTED FRAMES
# ============================================================

frames_folder = "/content/detected_frames"

if not os.path.exists(frames_folder):
    os.makedirs(frames_folder)


# ============================================================
# 11. OUTPUT VIDEO
# ============================================================

output_path = "/content/output3.avi"

fourcc = cv2.VideoWriter_fourcc(*"XVID")

out = cv2.VideoWriter(
    output_path,
    fourcc,
    fps,
    (1020, 500)
)

if not out.isOpened():
    raise ValueError(
        "Could not create output video"
    )


# ============================================================
# 12. FRAME COUNTER
# ============================================================

count = 0


# ============================================================
# 13. PROCESS VIDEO
# ============================================================

while True:

    ret, frame = cap.read()

    if not ret:
        break

    count += 1


    # ========================================================
    # RESIZE FRAME
    # ========================================================

    frame = cv2.resize(
        frame,
        (1020, 500)
    )


    # ========================================================
    # YOLO DETECTION
    # ========================================================

    results = model.predict(
        frame,
        verbose=False
    )


    # Get detection data

    a = results[0].boxes.data

    a = a.detach().cpu().numpy()

    px = pd.DataFrame(a).astype("float")


    # ========================================================
    # CAR DETECTIONS
    # ========================================================

    detections = []


    for index, row in px.iterrows():

        x1 = int(row[0])
        y1 = int(row[1])

        x2 = int(row[2])
        y2 = int(row[3])

        confidence = float(row[4])

        class_id = int(row[5])


        # Get class name

        c = class_list[class_id]


        # Only detect cars

        if c == "car":

            detections.append(
                [x1, y1, x2, y2]
            )


    # ========================================================
    # UPDATE TRACKER
    # ========================================================

    bbox_id = tracker.update(
        detections
    )


    # ========================================================
    # PROCESS TRACKED VEHICLES
    # ========================================================

    for bbox in bbox_id:

        x3, y3, x4, y4, vehicle_id = bbox


        x3 = int(x3)
        y3 = int(y3)

        x4 = int(x4)
        y4 = int(y4)

        vehicle_id = int(vehicle_id)


        # ====================================================
        # CENTER POINT
        # ====================================================

        cx = int(
            (x3 + x4) / 2
        )

        cy = int(
            (y3 + y4) / 2
        )


        # ====================================================
        # CURRENT VIDEO TIME
        # ====================================================

        current_video_time = (
            count / fps
        )


        # ====================================================
        # GOING DOWN
        #
        # RED LINE -> BLUE LINE
        # ====================================================

        if (
            red_line_y < (cy + offset)
            and
            red_line_y > (cy - offset)
        ):

            # Save frame/time only once

            if vehicle_id not in down:

                down[vehicle_id] = (
                    count,
                    current_video_time
                )

                print(
                    f"[Vehicle {vehicle_id}] "
                    f"RED line crossed "
                    f"(DOWN timer started)"
                )


        # ====================================================
        # CHECK BLUE LINE FOR DOWN VEHICLE
        # ====================================================

        if vehicle_id in down:

            if (
                blue_line_y < (cy + offset)
                and
                blue_line_y > (cy - offset)
            ):

                # Only calculate once

                if vehicle_id not in counter_down:

                    counter_down.append(
                        vehicle_id
                    )


                    # Get starting information

                    start_frame, start_time = (
                        down[vehicle_id]
                    )


                    # Current frame/time

                    end_frame = count

                    end_time = (
                        current_video_time
                    )


                    # Calculate elapsed video time

                    elapsed_time = (
                        end_time -
                        start_time
                    )


                    # Safety check

                    if elapsed_time > 0:

                        # Speed in meters/second

                        speed_ms = (
                            DISTANCE_METERS /
                            elapsed_time
                        )


                        # Speed in km/hour

                        speed_kmh = (
                            speed_ms * 3.6
                        )


                        # Store speed

                        speed_down[
                            vehicle_id
                        ] = speed_kmh


                        # ====================================
                        # PRINT SPEED IN COLAB OUTPUT
                        # ====================================

                        print(
                            "--------------------------------------"
                        )

                        print(
                            f"Vehicle ID : {vehicle_id}"
                        )

                        print(
                            "Direction  : DOWN"
                        )

                        print(
                            f"Start frame: {start_frame}"
                        )

                        print(
                            f"End frame  : {end_frame}"
                        )

                        print(
                            f"Elapsed    : "
                            f"{elapsed_time:.2f} sec"
                        )

                        print(
                            f"Distance   : "
                            f"{DISTANCE_METERS} m"
                        )

                        print(
                            f"Speed      : "
                            f"{speed_kmh:.2f} km/h"
                        )

                        print(
                            "--------------------------------------"
                        )


                        # ====================================
                        # DRAW VEHICLE
                        # ====================================

                        cv2.circle(
                            frame,
                            (cx, cy),
                            4,
                            (0, 0, 255),
                            -1
                        )


                        cv2.rectangle(
                            frame,
                            (x3, y3),
                            (x4, y4),
                            (0, 255, 0),
                            2
                        )


                        cv2.putText(
                            frame,
                            f"ID: {vehicle_id}",
                            (x3, y3),
                            cv2.FONT_HERSHEY_COMPLEX,
                            0.6,
                            (255, 255, 255),
                            1
                        )


                        cv2.putText(
                            frame,
                            f"{int(speed_kmh)} Km/h",
                            (x3, y4),
                            cv2.FONT_HERSHEY_COMPLEX,
                            0.8,
                            (0, 255, 255),
                            2
                        )


        # ====================================================
        # GOING UP
        #
        # BLUE LINE -> RED LINE
        # ====================================================

        if (
            blue_line_y < (cy + offset)
            and
            blue_line_y > (cy - offset)
        ):

            # Save frame/time only once

            if vehicle_id not in up:

                up[vehicle_id] = (
                    count,
                    current_video_time
                )

                print(
                    f"[Vehicle {vehicle_id}] "
                    f"BLUE line crossed "
                    f"(UP timer started)"
                )


        # ====================================================
        # CHECK RED LINE FOR UP VEHICLE
        # ====================================================

        if vehicle_id in up:

            if (
                red_line_y < (cy + offset)
                and
                red_line_y > (cy - offset)
            ):

                # Only calculate once

                if vehicle_id not in counter_up:

                    counter_up.append(
                        vehicle_id
                    )


                    # Get starting information

                    start_frame1, start_time1 = (
                        up[vehicle_id]
                    )


                    # Current frame/time

                    end_frame1 = count

                    end_time1 = (
                        current_video_time
                    )


                    # Calculate elapsed video time

                    elapsed1_time = (
                        end_time1 -
                        start_time1
                    )


                    # Safety check

                    if elapsed1_time > 0:

                        # Speed in m/s

                        speed_ms1 = (
                            DISTANCE_METERS /
                            elapsed1_time
                        )


                        # Speed in km/h

                        speed_kmh1 = (
                            speed_ms1 * 3.6
                        )


                        # Store speed

                        speed_up[
                            vehicle_id
                        ] = speed_kmh1


                        # ====================================
                        # PRINT SPEED IN COLAB OUTPUT
                        # ====================================

                        print(
                            "--------------------------------------"
                        )

                        print(
                            f"Vehicle ID : {vehicle_id}"
                        )

                        print(
                            "Direction  : UP"
                        )

                        print(
                            f"Start frame: {start_frame1}"
                        )

                        print(
                            f"End frame  : {end_frame1}"
                        )

                        print(
                            f"Elapsed    : "
                            f"{elapsed1_time:.2f} sec"
                        )

                        print(
                            f"Distance   : "
                            f"{DISTANCE_METERS} m"
                        )

                        print(
                            f"Speed      : "
                            f"{speed_kmh1:.2f} km/h"
                        )

                        print(
                            "--------------------------------------"
                        )


                        # ====================================
                        # DRAW VEHICLE
                        # ====================================

                        cv2.circle(
                            frame,
                            (cx, cy),
                            4,
                            (0, 0, 255),
                            -1
                        )


                        cv2.rectangle(
                            frame,
                            (x3, y3),
                            (x4, y4),
                            (0, 255, 0),
                            2
                        )


                        cv2.putText(
                            frame,
                            f"ID: {vehicle_id}",
                            (x3, y3),
                            cv2.FONT_HERSHEY_COMPLEX,
                            0.6,
                            (255, 255, 255),
                            1
                        )


                        cv2.putText(
                            frame,
                            f"{int(speed_kmh1)} Km/h",
                            (x3, y4),
                            cv2.FONT_HERSHEY_COMPLEX,
                            0.8,
                            (0, 255, 255),
                            2
                        )


    # ========================================================
    # COLORS
    # ========================================================

    text_color = (0, 0, 0)

    yellow_color = (0, 255, 255)

    red_color = (0, 0, 255)

    blue_color = (255, 0, 0)


    # ========================================================
    # TOP INFORMATION BOX
    # ========================================================

    cv2.rectangle(
        frame,
        (0, 0),
        (250, 90),
        yellow_color,
        -1
    )


    # ========================================================
    # RED LINE
    # ========================================================

    cv2.line(
        frame,
        (172, red_line_y),
        (774, red_line_y),
        red_color,
        2
    )

    cv2.putText(
        frame,
        "Red Line",
        (172, red_line_y),
        cv2.FONT_HERSHEY_SIMPLEX,
        0.5,
        text_color,
        1,
        cv2.LINE_AA
    )


    # ========================================================
    # BLUE LINE
    # ========================================================

    cv2.line(
        frame,
        (8, blue_line_y),
        (927, blue_line_y),
        blue_color,
        2
    )

    cv2.putText(
        frame,
        "Blue Line",
        (8, blue_line_y),
        cv2.FONT_HERSHEY_SIMPLEX,
        0.5,
        text_color,
        1,
        cv2.LINE_AA
    )


    # ========================================================
    # COUNTERS
    # ========================================================

    cv2.putText(
        frame,
        "Going Down - "
        + str(len(counter_down)),
        (10, 30),
        cv2.FONT_HERSHEY_SIMPLEX,
        0.5,
        text_color,
        1,
        cv2.LINE_AA
    )


    cv2.putText(
        frame,
        "Going Up - "
        + str(len(counter_up)),
        (10, 60),
        cv2.FONT_HERSHEY_SIMPLEX,
        0.5,
        text_color,
        1,
        cv2.LINE_AA
    )


    # ========================================================
    # SAVE FRAME
    # ========================================================

    frame_filename = (
        f"{frames_folder}/frame_{count}.jpg"
    )

    cv2.imwrite(
        frame_filename,
        frame
    )


    # ========================================================
    # WRITE VIDEO
    # ========================================================

    out.write(frame)


    # ========================================================
    # PROGRESS
    # ========================================================

    if count % 100 == 0:

        progress = (
            count / total_frames * 100
            if total_frames > 0
            else 0
        )

        print(
            f"Processing: "
            f"{count}/{total_frames} "
            f"({progress:.1f}%)"
        )


# ============================================================
# 14. RELEASE VIDEO
# ============================================================

cap.release()
out.release()


# ============================================================
# 15. FINAL RESULTS
# ============================================================

print("\n")
print("===================================================")
print("                 PROCESSING COMPLETE")
print("===================================================")

print(
    f"Total frames processed : {count}"
)

print(
    f"Vehicles going DOWN    : "
    f"{len(counter_down)}"
)

print(
    f"Vehicles going UP      : "
    f"{len(counter_up)}"
)


# ============================================================
# 16. PRINT ALL SPEED RESULTS
# ============================================================

print("\n")
print("===================================================")
print("                 SPEED RESULTS")
print("===================================================")


if len(speed_down) > 0:

    print("\nGOING DOWN:")

    for vehicle_id, speed in speed_down.items():

        print(
            f"Vehicle {vehicle_id} "
            f"-> {speed:.2f} km/h"
        )


if len(speed_up) > 0:

    print("\nGOING UP:")

    for vehicle_id, speed in speed_up.items():

        print(
            f"Vehicle {vehicle_id} "
            f"-> {speed:.2f} km/h"
        )


if len(speed_down) == 0 and len(speed_up) == 0:

    print(
        "\nNo vehicles completed both line crossings."
    )


print("\n")
print(
    f"Output video: {output_path}"
)
# Out:
# YOLO26m loaded successfully
# Video opened successfully
# --------------------------------------
# Video FPS       : 25.00
# Total frames    : 1060
# Original size   : 1920 x 1080
# Duration        : 42.40 seconds
# --------------------------------------
# YOLO Classes:
# {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# [Vehicle 2] RED line crossed (DOWN timer started)
# [Vehicle 0] RED line crossed (DOWN timer started)
# [Vehicle 16] BLUE line crossed (UP timer started)
# [Vehicle 19] BLUE line crossed (UP timer started)
# [Vehicle 4] RED line crossed (DOWN timer started)
# [Vehicle 16] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 16
# Direction  : UP
# Start frame: 35
# End frame  : 63
# Elapsed    : 1.12 sec
# Distance   : 10 m
# Speed      : 32.14 km/h
# --------------------------------------
# [Vehicle 40] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 4
# Direction  : DOWN
# Start frame: 46
# End frame  : 72
# Elapsed    : 1.04 sec
# Distance   : 10 m
# Speed      : 34.62 km/h
# --------------------------------------
# [Vehicle 4] BLUE line crossed (UP timer started)
# [Vehicle 49] BLUE line crossed (UP timer started)
# Processing: 100/1060 (9.4%)
# [Vehicle 62] RED line crossed (DOWN timer started)
# [Vehicle 49] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 49
# Direction  : UP
# Start frame: 87
# End frame  : 112
# Elapsed    : 1.00 sec
# Distance   : 10 m
# Speed      : 36.00 km/h
# --------------------------------------
# [Vehicle 35] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 62
# Direction  : DOWN
# Start frame: 110
# End frame  : 135
# Elapsed    : 1.00 sec
# Distance   : 10 m
# Speed      : 36.00 km/h
# --------------------------------------
# [Vehicle 62] BLUE line crossed (UP timer started)
# [Vehicle 63] RED line crossed (DOWN timer started)
# [Vehicle 29] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 63
# Direction  : DOWN
# Start frame: 135
# End frame  : 158
# Elapsed    : 0.92 sec
# Distance   : 10 m
# Speed      : 39.13 km/h
# --------------------------------------
# [Vehicle 63] BLUE line crossed (UP timer started)
# [Vehicle 83] BLUE line crossed (UP timer started)
# --------------------------------------
# Vehicle ID : 35
# Direction  : DOWN
# Start frame: 134
# End frame  : 164
# Elapsed    : 1.20 sec
# Distance   : 10 m
# Speed      : 30.00 km/h
# --------------------------------------
# [Vehicle 35] BLUE line crossed (UP timer started)
# [Vehicle 88] BLUE line crossed (UP timer started)
# --------------------------------------
# Vehicle ID : 29
# Direction  : DOWN
# Start frame: 140
# End frame  : 177
# Elapsed    : 1.48 sec
# Distance   : 10 m
# Speed      : 24.32 km/h
# --------------------------------------
# [Vehicle 29] BLUE line crossed (UP timer started)
# [Vehicle 92] BLUE line crossed (UP timer started)
# [Vehicle 88] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 88
# Direction  : UP
# Start frame: 164
# End frame  : 190
# Elapsed    : 1.04 sec
# Distance   : 10 m
# Speed      : 34.62 km/h
# --------------------------------------
# [Vehicle 111] RED line crossed (DOWN timer started)
# [Vehicle 83] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 83
# Direction  : UP
# Start frame: 162
# End frame  : 194
# Elapsed    : 1.28 sec
# Distance   : 10 m
# Speed      : 28.13 km/h
# --------------------------------------
# [Vehicle 104] BLUE line crossed (UP timer started)
# Processing: 200/1060 (18.9%)
# [Vehicle 108] BLUE line crossed (UP timer started)
# [Vehicle 92] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 92
# Direction  : UP
# Start frame: 181
# End frame  : 214
# Elapsed    : 1.32 sec
# Distance   : 10 m
# Speed      : 27.27 km/h
# --------------------------------------
# --------------------------------------
# Vehicle ID : 111
# Direction  : DOWN
# Start frame: 190
# End frame  : 220
# Elapsed    : 1.20 sec
# Distance   : 10 m
# Speed      : 30.00 km/h
# --------------------------------------
# [Vehicle 111] BLUE line crossed (UP timer started)
# [Vehicle 104] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 104
# Direction  : UP
# Start frame: 199
# End frame  : 224
# Elapsed    : 1.00 sec
# Distance   : 10 m
# Speed      : 36.00 km/h
# --------------------------------------
# [Vehicle 121] BLUE line crossed (UP timer started)
# [Vehicle 140] RED line crossed (DOWN timer started)
# [Vehicle 106] RED line crossed (DOWN timer started)
# [Vehicle 153] BLUE line crossed (UP timer started)
# [Vehicle 142] BLUE line crossed (UP timer started)
# [Vehicle 121] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 121
# Direction  : UP
# Start frame: 225
# End frame  : 266
# Elapsed    : 1.64 sec
# Distance   : 10 m
# Speed      : 21.95 km/h
# --------------------------------------
# [Vehicle 153] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 153
# Direction  : UP
# Start frame: 255
# End frame  : 282
# Elapsed    : 1.08 sec
# Distance   : 10 m
# Speed      : 33.33 km/h
# --------------------------------------
# --------------------------------------
# Vehicle ID : 106
# Direction  : DOWN
# Start frame: 253
# End frame  : 284
# Elapsed    : 1.24 sec
# Distance   : 10 m
# Speed      : 29.03 km/h
# --------------------------------------
# [Vehicle 106] BLUE line crossed (UP timer started)
# [Vehicle 142] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 142
# Direction  : UP
# Start frame: 256
# End frame  : 289
# Elapsed    : 1.32 sec
# Distance   : 10 m
# Speed      : 27.27 km/h
# --------------------------------------
# Processing: 300/1060 (28.3%)
# [Vehicle 159] BLUE line crossed (UP timer started)
# [Vehicle 159] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 159
# Direction  : UP
# Start frame: 301
# End frame  : 328
# Elapsed    : 1.08 sec
# Distance   : 10 m
# Speed      : 33.33 km/h
# --------------------------------------
# [Vehicle 173] BLUE line crossed (UP timer started)
# [Vehicle 188] BLUE line crossed (UP timer started)
# [Vehicle 200] BLUE line crossed (UP timer started)
# [Vehicle 181] RED line crossed (DOWN timer started)
# [Vehicle 173] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 173
# Direction  : UP
# Start frame: 332
# End frame  : 368
# Elapsed    : 1.44 sec
# Distance   : 10 m
# Speed      : 25.00 km/h
# --------------------------------------
# [Vehicle 198] BLUE line crossed (UP timer started)
# [Vehicle 200] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 200
# Direction  : UP
# Start frame: 350
# End frame  : 377
# Elapsed    : 1.08 sec
# Distance   : 10 m
# Speed      : 33.33 km/h
# --------------------------------------
# [Vehicle 202] BLUE line crossed (UP timer started)
# [Vehicle 188] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 188
# Direction  : UP
# Start frame: 346
# End frame  : 385
# Elapsed    : 1.56 sec
# Distance   : 10 m
# Speed      : 23.08 km/h
# --------------------------------------
# [Vehicle 232] RED line crossed (DOWN timer started)
# [Vehicle 237] RED line crossed (DOWN timer started)
# [Vehicle 236] BLUE line crossed (UP timer started)
# Processing: 400/1060 (37.7%)
# [Vehicle 227] RED line crossed (DOWN timer started)
# [Vehicle 242] RED line crossed (DOWN timer started)
# [Vehicle 219] RED line crossed (DOWN timer started)
# [Vehicle 202] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 202
# Direction  : UP
# Start frame: 381
# End frame  : 411
# Elapsed    : 1.20 sec
# Distance   : 10 m
# Speed      : 30.00 km/h
# --------------------------------------
# [Vehicle 239] BLUE line crossed (UP timer started)
# [Vehicle 253] BLUE line crossed (UP timer started)
# --------------------------------------
# Vehicle ID : 219
# Direction  : DOWN
# Start frame: 404
# End frame  : 428
# Elapsed    : 0.96 sec
# Distance   : 10 m
# Speed      : 37.50 km/h
# --------------------------------------
# [Vehicle 219] BLUE line crossed (UP timer started)
# [Vehicle 268] BLUE line crossed (UP timer started)
# [Vehicle 263] RED line crossed (DOWN timer started)
# [Vehicle 192] RED line crossed (DOWN timer started)
# [Vehicle 266] BLUE line crossed (UP timer started)
# [Vehicle 239] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 239
# Direction  : UP
# Start frame: 422
# End frame  : 456
# Elapsed    : 1.36 sec
# Distance   : 10 m
# Speed      : 26.47 km/h
# --------------------------------------
# [Vehicle 293] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 263
# Direction  : DOWN
# Start frame: 440
# End frame  : 462
# Elapsed    : 0.88 sec
# Distance   : 10 m
# Speed      : 40.91 km/h
# --------------------------------------
# [Vehicle 263] BLUE line crossed (UP timer started)
# [Vehicle 289] RED line crossed (DOWN timer started)
# [Vehicle 266] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 266
# Direction  : UP
# Start frame: 451
# End frame  : 477
# Elapsed    : 1.04 sec
# Distance   : 10 m
# Speed      : 34.62 km/h
# --------------------------------------
# --------------------------------------
# Vehicle ID : 293
# Direction  : DOWN
# Start frame: 458
# End frame  : 480
# Elapsed    : 0.88 sec
# Distance   : 10 m
# Speed      : 40.91 km/h
# --------------------------------------
# [Vehicle 293] BLUE line crossed (UP timer started)
# --------------------------------------
# Vehicle ID : 192
# Direction  : DOWN
# Start frame: 445
# End frame  : 480
# Elapsed    : 1.40 sec
# Distance   : 10 m
# Speed      : 25.71 km/h
# --------------------------------------
# [Vehicle 192] BLUE line crossed (UP timer started)
# [Vehicle 306] BLUE line crossed (UP timer started)
# --------------------------------------
# Vehicle ID : 289
# Direction  : DOWN
# Start frame: 476
# End frame  : 498
# Elapsed    : 0.88 sec
# Distance   : 10 m
# Speed      : 40.91 km/h
# --------------------------------------
# [Vehicle 289] BLUE line crossed (UP timer started)
# Processing: 500/1060 (47.2%)
# [Vehicle 325] RED line crossed (DOWN timer started)
# [Vehicle 306] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 306
# Direction  : UP
# Start frame: 481
# End frame  : 505
# Elapsed    : 0.96 sec
# Distance   : 10 m
# Speed      : 37.50 km/h
# --------------------------------------
# [Vehicle 324] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 325
# Direction  : DOWN
# Start frame: 503
# End frame  : 526
# Elapsed    : 0.92 sec
# Distance   : 10 m
# Speed      : 39.13 km/h
# --------------------------------------
# [Vehicle 325] BLUE line crossed (UP timer started)
# [Vehicle 344] BLUE line crossed (UP timer started)
# --------------------------------------
# Vehicle ID : 324
# Direction  : DOWN
# Start frame: 526
# End frame  : 550
# Elapsed    : 0.96 sec
# Distance   : 10 m
# Speed      : 37.50 km/h
# --------------------------------------
# [Vehicle 324] BLUE line crossed (UP timer started)
# [Vehicle 340] RED line crossed (DOWN timer started)
# [Vehicle 344] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 344
# Direction  : UP
# Start frame: 544
# End frame  : 563
# Elapsed    : 0.76 sec
# Distance   : 10 m
# Speed      : 47.37 km/h
# --------------------------------------
# [Vehicle 320] RED line crossed (DOWN timer started)
# [Vehicle 377] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 340
# Direction  : DOWN
# Start frame: 553
# End frame  : 577
# Elapsed    : 0.96 sec
# Distance   : 10 m
# Speed      : 37.50 km/h
# --------------------------------------
# [Vehicle 340] BLUE line crossed (UP timer started)
# --------------------------------------
# Vehicle ID : 320
# Direction  : DOWN
# Start frame: 564
# End frame  : 595
# Elapsed    : 1.24 sec
# Distance   : 10 m
# Speed      : 29.03 km/h
# --------------------------------------
# [Vehicle 320] BLUE line crossed (UP timer started)
# [Vehicle 364] RED line crossed (DOWN timer started)
# Processing: 600/1060 (56.6%)
# [Vehicle 373] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 364
# Direction  : DOWN
# Start frame: 598
# End frame  : 622
# Elapsed    : 0.96 sec
# Distance   : 10 m
# Speed      : 37.50 km/h
# --------------------------------------
# [Vehicle 364] BLUE line crossed (UP timer started)
# --------------------------------------
# Vehicle ID : 373
# Direction  : DOWN
# Start frame: 622
# End frame  : 651
# Elapsed    : 1.16 sec
# Distance   : 10 m
# Speed      : 31.03 km/h
# --------------------------------------
# [Vehicle 373] BLUE line crossed (UP timer started)
# [Vehicle 436] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 436
# Direction  : DOWN
# Start frame: 664
# End frame  : 688
# Elapsed    : 0.96 sec
# Distance   : 10 m
# Speed      : 37.50 km/h
# --------------------------------------
# [Vehicle 436] BLUE line crossed (UP timer started)
# Processing: 700/1060 (66.0%)
# [Vehicle 434] RED line crossed (DOWN timer started)
# [Vehicle 491] BLUE line crossed (UP timer started)
# [Vehicle 479] BLUE line crossed (UP timer started)
# [Vehicle 478] BLUE line crossed (UP timer started)
# [Vehicle 479] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 479
# Direction  : UP
# Start frame: 749
# End frame  : 771
# Elapsed    : 0.88 sec
# Distance   : 10 m
# Speed      : 40.91 km/h
# --------------------------------------
# [Vehicle 478] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 478
# Direction  : UP
# Start frame: 754
# End frame  : 783
# Elapsed    : 1.16 sec
# Distance   : 10 m
# Speed      : 31.03 km/h
# --------------------------------------
# [Vehicle 507] BLUE line crossed (UP timer started)
# Processing: 800/1060 (75.5%)
# [Vehicle 520] BLUE line crossed (UP timer started)
# [Vehicle 507] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 507
# Direction  : UP
# Start frame: 795
# End frame  : 823
# Elapsed    : 1.12 sec
# Distance   : 10 m
# Speed      : 32.14 km/h
# --------------------------------------
# [Vehicle 482] RED line crossed (DOWN timer started)
# [Vehicle 529] RED line crossed (DOWN timer started)
# [Vehicle 520] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 520
# Direction  : UP
# Start frame: 823
# End frame  : 846
# Elapsed    : 0.92 sec
# Distance   : 10 m
# Speed      : 39.13 km/h
# --------------------------------------
# --------------------------------------
# Vehicle ID : 482
# Direction  : DOWN
# Start frame: 833
# End frame  : 858
# Elapsed    : 1.00 sec
# Distance   : 10 m
# Speed      : 36.00 km/h
# --------------------------------------
# [Vehicle 482] BLUE line crossed (UP timer started)
# [Vehicle 537] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 529
# Direction  : DOWN
# Start frame: 845
# End frame  : 871
# Elapsed    : 1.04 sec
# Distance   : 10 m
# Speed      : 34.62 km/h
# --------------------------------------
# [Vehicle 529] BLUE line crossed (UP timer started)
# [Vehicle 528] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 537
# Direction  : DOWN
# Start frame: 861
# End frame  : 882
# Elapsed    : 0.84 sec
# Distance   : 10 m
# Speed      : 42.86 km/h
# --------------------------------------
# [Vehicle 537] BLUE line crossed (UP timer started)
# [Vehicle 543] RED line crossed (DOWN timer started)
# [Vehicle 550] BLUE line crossed (UP timer started)
# Processing: 900/1060 (84.9%)
# --------------------------------------
# Vehicle ID : 543
# Direction  : DOWN
# Start frame: 888
# End frame  : 909
# Elapsed    : 0.84 sec
# Distance   : 10 m
# Speed      : 42.86 km/h
# --------------------------------------
# [Vehicle 543] BLUE line crossed (UP timer started)
# --------------------------------------
# Vehicle ID : 528
# Direction  : DOWN
# Start frame: 881
# End frame  : 911
# Elapsed    : 1.20 sec
# Distance   : 10 m
# Speed      : 30.00 km/h
# --------------------------------------
# [Vehicle 528] BLUE line crossed (UP timer started)
# [Vehicle 550] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 550
# Direction  : UP
# Start frame: 888
# End frame  : 916
# Elapsed    : 1.12 sec
# Distance   : 10 m
# Speed      : 32.14 km/h
# --------------------------------------
# [Vehicle 552] RED line crossed (DOWN timer started)
# [Vehicle 585] BLUE line crossed (UP timer started)
# [Vehicle 584] RED line crossed (DOWN timer started)
# [Vehicle 585] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 585
# Direction  : UP
# Start frame: 955
# End frame  : 984
# Elapsed    : 1.16 sec
# Distance   : 10 m
# Speed      : 31.03 km/h
# --------------------------------------
# --------------------------------------
# Vehicle ID : 552
# Direction  : DOWN
# Start frame: 955
# End frame  : 986
# Elapsed    : 1.24 sec
# Distance   : 10 m
# Speed      : 29.03 km/h
# --------------------------------------
# [Vehicle 552] BLUE line crossed (UP timer started)
# --------------------------------------
# Vehicle ID : 584
# Direction  : DOWN
# Start frame: 965
# End frame  : 987
# Elapsed    : 0.88 sec
# Distance   : 10 m
# Speed      : 40.91 km/h
# --------------------------------------
# [Vehicle 584] BLUE line crossed (UP timer started)
# Processing: 1000/1060 (94.3%)
# [Vehicle 595] BLUE line crossed (UP timer started)
# [Vehicle 577] RED line crossed (DOWN timer started)
# [Vehicle 605] BLUE line crossed (UP timer started)
# [Vehicle 595] RED line crossed (DOWN timer started)
# --------------------------------------
# Vehicle ID : 595
# Direction  : UP
# Start frame: 1001
# End frame  : 1030
# Elapsed    : 1.16 sec
# Distance   : 10 m
# Speed      : 31.03 km/h
# --------------------------------------
# --------------------------------------
# Vehicle ID : 577
# Direction  : DOWN
# Start frame: 1007
# End frame  : 1037
# Elapsed    : 1.20 sec
# Distance   : 10 m
# Speed      : 30.00 km/h
# --------------------------------------
# [Vehicle 577] BLUE line crossed (UP timer started)
# [Vehicle 620] RED line crossed (DOWN timer started)
# [Vehicle 581] RED line crossed (DOWN timer started)
#
#
# ===================================================
#                  PROCESSING COMPLETE
# ===================================================
# Total frames processed : 1060
# Vehicles going DOWN    : 27
# Vehicles going UP      : 25
#
#
# ===================================================
#                  SPEED RESULTS
# ===================================================
#
# GOING DOWN:
# Vehicle 4 -> 34.62 km/h
# Vehicle 62 -> 36.00 km/h
# Vehicle 63 -> 39.13 km/h
# Vehicle 35 -> 30.00 km/h
# Vehicle 29 -> 24.32 km/h
# Vehicle 111 -> 30.00 km/h
# Vehicle 106 -> 29.03 km/h
# Vehicle 219 -> 37.50 km/h
# Vehicle 263 -> 40.91 km/h
# Vehicle 293 -> 40.91 km/h
# Vehicle 192 -> 25.71 km/h
# Vehicle 289 -> 40.91 km/h
# Vehicle 325 -> 39.13 km/h
# Vehicle 324 -> 37.50 km/h
# Vehicle 340 -> 37.50 km/h
# Vehicle 320 -> 29.03 km/h
# Vehicle 364 -> 37.50 km/h
# Vehicle 373 -> 31.03 km/h
# Vehicle 436 -> 37.50 km/h
# Vehicle 482 -> 36.00 km/h
# Vehicle 529 -> 34.62 km/h
# Vehicle 537 -> 42.86 km/h
# Vehicle 543 -> 42.86 km/h
# Vehicle 528 -> 30.00 km/h
# Vehicle 552 -> 29.03 km/h
# Vehicle 584 -> 40.91 km/h
# Vehicle 577 -> 30.00 km/h
#
# GOING UP:
# Vehicle 16 -> 32.14 km/h
# Vehicle 49 -> 36.00 km/h
# Vehicle 88 -> 34.62 km/h
# Vehicle 83 -> 28.13 km/h
# Vehicle 92 -> 27.27 km/h
# Vehicle 104 -> 36.00 km/h
# Vehicle 121 -> 21.95 km/h
# Vehicle 153 -> 33.33 km/h
# Vehicle 142 -> 27.27 km/h
# Vehicle 159 -> 33.33 km/h
# Vehicle 173 -> 25.00 km/h
# Vehicle 200 -> 33.33 km/h
# Vehicle 188 -> 23.08 km/h
# Vehicle 202 -> 30.00 km/h
# Vehicle 239 -> 26.47 km/h
# Vehicle 266 -> 34.62 km/h
# Vehicle 306 -> 37.50 km/h
# Vehicle 344 -> 47.37 km/h
# Vehicle 479 -> 40.91 km/h
# Vehicle 478 -> 31.03 km/h
# Vehicle 507 -> 32.14 km/h
# Vehicle 520 -> 39.13 km/h
# Vehicle 550 -> 32.14 km/h
# Vehicle 585 -> 31.03 km/h
# Vehicle 595 -> 31.03 km/h
#
#
# Output video: /content/output3.avi
