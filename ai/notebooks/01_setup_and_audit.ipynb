# %% [markdown]
# # ANPR Character Pipeline — Setup & Audit
# Upload only your `best.pt` and your dataset. The reference LPSR/character assets are downloaded automatically.

# %%
# %cd /content/anpr_character_pipeline
# !pip install -q -r requirements.txt
# !python scripts/setup_colab.py
# !python scripts/audit_project.py

# %% [markdown]
# ## Expected model layout
# `models/best.pt` = your plate detector
# `models/lpsr_best.pth` = downloaded LPSR
# `models/char.pt` = downloaded reference character detector
# `classes/ocr_class_names.txt` = downloaded class names

# %%
from pathlib import Path
from config import MODELS, DATA, CLASSES, REF_REPO_DIR
print('MODELS:', list(MODELS.iterdir()))
print('DATA files:', [str(p.relative_to(DATA)) for p in DATA.rglob('*') if p.is_file()][:20])
print('REF REPO:', REF_REPO_DIR.exists())
